# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression


# 다항회귀 모듈 인스턴스 생성
poly = PolynomialFeatures(include_bias = False)


# 농어의 너비 csv 파일 읽기
perch_full = pd.read_csv('https://raw.githubusercontent.com/rickiepark/hg-mldl/master/perch_full.csv')
perch_full.head()   #data frame의 5개 행 불러오기


# 농어 무게 data 2차원 배열 만들기
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])


# 훈련 세트, 테스트 세트 데이터 분배
train_input, test_input, train_target, test_target = train_test_split(perch_full, perch_weight, random_state = 42)

poly.fit(train_input)
train_poly = poly.transform(train_input)
print(train_poly.shape)


# 9개의 특성 어떤 입력 조합으로 만들었는지 확인
poly.get_feature_names_out()

test_poly = poly.transform(test_input)

lr = LinearRegression()
lr.fit(train_poly, train_target)

# 훈련 세트 평가
print(lr.score(train_poly, train_target))

# 테스트 세트 평가
print(lr.score(test_poly, test_target))



poly = PolynomialFeatures(degree = 5, include_bias = False)    # 필요한 고차항 최대 차수 지정하기
poly.fit(train_input)       # 선형모델 training
train_poly = poly.transform(train_input)  # 훈련모델 형 변환
test_poly = poly.transform(test_input)    # 테스트 모델 형 변환


# 선형회귀 모델 재훈련
lr.fit(train_poly, train_target)
print(lr.score(train_poly, train_target))

# 특성 만들기 / 전처리
# 선형 방정식 절편 (길이, 높이, 두께, 1) 자동 추가
# 무게 = a * 길이 + b * 높이 + c * 두께
# print(poly.transform([[2, 3]]))
# Out:
# (42, 9)
# 0.9903183436982124
# 0.9714559911594145
# 0.9999999999996176
